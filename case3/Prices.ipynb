# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#%matplotlib inline

# %%
prices_test = pd.read_csv('Prices/test.csv')
prices_train = pd.read_csv('Prices/train.csv')

# %%
prices_test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
prices_test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
prices_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
prices_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
prices_test.shape
# Out:
# (1459, 80)

# %%
prices_train.shape
# Out:
# (1460, 81)

# %%
 sns.pairplot(data=prices_train,
                  y_vars=['SalePrice'], x_vars = ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice'] )

# %%
corr = prices_train.corr()["SalePrice"]
corr.sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
#corr_2 =  prices_train.corr(method ='pearson')

# %%
# sns.set()
# columns = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', '1stFlrSF','FullBath',
# 'TotRmsAbvGrd', 'YearBuilt','YearRemodAdd']
# sns.pairplot(prices_train[columns], size = 4)
# plt.show();

# %%
plt.scatter(prices_train['GrLivArea'], prices_train['SalePrice'])
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
plt.scatter(prices_train['OverallQual'], prices_train['SalePrice'])
plt.xlabel('OverallQual')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
n = prices_train.shape[0]
for col in prices_train.columns:
    missing_pct = sum(prices_train[col].isnull())*100/n
    if missing_pct > 50.0:
        print(f'{col}: {missing_pct:0.2f}%')
# Out:
# Alley: 93.77%
# PoolQC: 99.52%
# Fence: 80.75%
# MiscFeature: 96.30%

# %%
# df_train.drop(['PoolQC', 'MiscFeature'], axis=1, inplace=True)
# df_test.drop(['PoolQC', 'MiscFeature'], axis=1, inplace=True)

# %%
sns.heatmap(prices_train.isnull(), yticklabels=False, cbar = False, cmap = 'viridis')

# %%
# categor = prices_train['SalePrice'].corr(prices_train['MSSubClass'])
# print(categor)
# Out:
# -0.08428413512659523

# %%
corrMatrix =
# Out:
#   File "<ipython-input-238-897963f20b86>", line 1
#     prices_train['SalePrice'].corr() = prices_train.columns
#                                                            ^
# SyntaxError: can't assign to function call

# %%
plt.subplots(figsize=(35,20))
sns.heatmap(corrMatrix,annot = True)

# %%
# Corr Matrix, sravnqva vsqko s vsqko

corrMatrix = prices_train.corr()
print(corrMatrix)
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
# unstack pravi pivot tablica pri multiindexirane
# sort_values, sortira stoinostite vuv vuzhodqsht red (pri ascending = True, v nizhodqsht)

s = corrMatrix.unstack()
so = s.sort_values(ascending=False)
largest_values = so[38:].nlargest(n=51)

print(largest_values)
# Out:
# GarageCars    GarageArea      0.882475
# GarageArea    GarageCars      0.882475
# GarageYrBlt   YearBuilt       0.825667
# YearBuilt     GarageYrBlt     0.825667
# GrLivArea     TotRmsAbvGrd    0.825489
# TotRmsAbvGrd  GrLivArea       0.825489
# 1stFlrSF      TotalBsmtSF     0.819530
# TotalBsmtSF   1stFlrSF        0.819530
# SalePrice     OverallQual     0.790982
# OverallQual   SalePrice       0.790982
# GrLivArea     SalePrice       0.708624
# SalePrice     GrLivArea       0.708624
# GrLivArea     2ndFlrSF        0.687501
# 2ndFlrSF      GrLivArea       0.687501
# BedroomAbvGr  TotRmsAbvGrd    0.676620
# TotRmsAbvGrd  BedroomAbvGr    0.676620
# BsmtFinSF1    BsmtFullBath    0.649212
# BsmtFullBath  BsmtFinSF1      0.649212
# GarageYrBlt   YearRemodAdd    0.642277
# YearRemodAdd  GarageYrBlt     0.642277
# SalePrice     GarageCars      0.640409
# GarageCars    SalePrice       0.640409
# FullBath      GrLivArea       0.630012
# GrLivArea     FullBath        0.630012
# ...

# %%
print("Skewness: %f" % prices_train['SalePrice'].skew())
print("Kurtosis: %f" % prices_train['SalePrice'].kurt())
sns.distplot(prices_train['SalePrice']);
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %%
 prices_train['SalePrice_Log'] = np.log(prices_train['SalePrice'])

 print("Skewness: %f" % prices_train['SalePrice_Log'].skew())
 print("Kurtosis: %f" % prices_train['SalePrice_Log'].kurt())
sns.distplot(prices_train['SalePrice_Log']);


# sns.distplot(prices_train['SalePrice_Log']);
# Out:
# Skewness: 0.121335
# Kurtosis: 0.809532

# %%
# def fill_missing_data(df):
#     prices_train = df.copy()
#     categoricals = []
#     for cname,dtype in prices_train.dtypes.items():
#         if dtype == 'object':
#             categoricals.append(cname)
#     # 'None' for Categorical 
#     prices_train[categoricals] = prices_train[categoricals].fillna('None')
    
#     for cname in prices_train.columns:
#         if cname not in categoricals:
#             prices_train[cname] = prices_train[cname].fillna(0) # 0 for the Numerics
#     return prices_train

# %%
#Total = 'BsmtFullBath' 'FullBath'+ (0.5*?)'BsmtHalfBath' + 'HalfBath'
#'Total_Area' = 'TotalBsmtSF' + 'GrLivArea'
#Total_Age = 'YrSold' - 'YearBuilt'
