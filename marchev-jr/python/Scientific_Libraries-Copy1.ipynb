# %% [markdown]
# Numpy
# <p>
#     Numpy solves one essential problem very fast: array processing
# <p>
#     It is also very fast with problems that are naturally vectorized, like matrix multiplication and linear algebra routines, vectors generation and application of fixed transformation over entire array.
# <p>    Numpy array is the most important data type when working with numpy. Data in numpy array must be homogenous. And data types must be ones that are provided by numpy.

# %%
import numpy as np

x = np.random.uniform(0, 1, size=1000000)
x.mean()
# Out:
# 0.49975362197510353

# %%
x
# Out:
# array([0.43256886, 0.23114671, 0.13892836, ..., 0.77979689, 0.95159935,
#        0.39477188])

# %%
x
# Out:
# array([0.99547565, 0.96576705, 0.83218607, ..., 0.16885037, 0.36565164,
#        0.08471152])

# %%
a = np.zeros(3)
a
type(a)
# Out:
# numpy.ndarray

# %%
a
# Out:
# array([0., 0., 0.])

# %%
# Shape and dimensions
a.shape
# Out:
# (3,)

# %%
# Reshape array
z = np.zeros(4)
z.shape = (2, 2)
z
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
# Create arrays in memory that can later be populated with data

z = np.empty(3)
z
# Out:
# array([0., 0., 0.])

# %%
# Set an array of eventy spaced numbers
z = np.linspace(2, 4, 5)  # From 2 to 4, with 5 elements

# %%
# Create an identity matrix
z = np.identity(3)
z
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# Create array from python list
z = np.array([10, 20])
z
# Out:
# array([10, 20])

# %%
# Set type for the array elements
z = np.array((10, 20), dtype=float)
z
# Out:
# array([10., 20.])

# %%
# Array indexing
z = np.linspace(1, 2, 5)
z
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
print(z[0])
print(z[1])
print(z[-1])
# Out:
# 1.0
# 1.25
# 2.0

# %%
# 2D arrays operations
z = np.array([[1, 2], [3, 4]])
print(z)

# Indexing
print(z[0, 0])
print(z[1, 0])

# Extract columns and rows
print(z[0, :])
print(z[:, 1])
# Out:
# [[1 2]
#  [3 4]]
# 1
# 3
# [1 2]
# [2 4]

# %%
new = z[0, :]

# %%
# Array methods
a = np.array((4, 3, 2, 1))

# mean, sort, sum, etc.
a.mean()
a.sum() 
a.sort()
a.max()
a.argmax() # return index of max element
a.cumsum() # cumulative sum of a elements
a.cumprod()
a.var() 
a.std() # standard deviation

a.T # equivalent to a.transpose()

#use functions above from the np namespace
np.mean(a)
# Out:
# 2.5

# %%
# Operations on array

a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])
a + b

a * b
a+10
a * 10
# Out:
# array([10, 20, 30, 40])

# %%
a + b
# Out:
# array([ 6,  8, 10, 12])

# %%
# Operations on 2D array
A = np.ones((2, 2))
B = np.ones((2, 2))
A + B
A + 10
A * B # Element-wise product, not matrix product
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
A + B
# Out:
# array([[2., 2.],
#        [2., 2.]])

# %%
# Matrix multiplication

A = np.ones((2, 2))
B = np.ones((2, 2))
A @ B
# Out:
# array([[2., 2.],
#        [2., 2.]])

# %%
# Making copies

b = np.copy(a)

# %%
b= a

# %%
# Vectorized funcitons

z = np.array([1, 2, 3])
np.sin(z)
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
x = np.random.randn(4)
x
np.where(x > 0, 1, 0)  # Insert 1 if x > 0 true, otherwise 0
# Out:
# array([1, 0, 1, 0])

# %%
x
# Out:
# array([ 0.64164412, -1.14020211,  0.41211572, -0.63447757])

# %%
# Vectorizing a user-defined function
def f(x): return 1 if x > 0 else 0

f = np.vectorize(f)
f(x)
# Out:
# array([1, 0, 1, 0])

# %%
# Comparisons are done element-wise
z = np.array([2, 3])
y = np.array([2, 3])
z == y
z != y
z > 3

b = z > 3
b
z[b]

# %%
# Subpackages
z = np.random.randn(10000)  # Generate standard normals
y = np.random.binomial(10, 0.5, size=1000)    # 1,000 draws from Bin(10, 0.5)
y.mean()


A = np.array([[1, 2], [3, 4]])
np.linalg.det(A)           # Compute the determinant


np.linalg.inv(A)           # Compute the inverse

# %% [markdown]
# Matplotlib
# <p> Matplotlib is a graphic library designed for high 2D and 3D plots. It has output in most common formats (PDF, PNG, etc.) and LaTex integration.

# %%
# Plot a sine function with matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.plot(x, y, 'b-', linewidth=2)
plt.show()

# %%
# Object oriented API and tweaks
fig, ax = plt.subplots()
ax.plot(x, y, 'r-', linewidth=2, label='$y=\sin(x)$', alpha=0.6)
ax.legend(loc='upper center')
ax.set_yticks([-1, 0, 1])
ax.set_title('Test plot')
plt.show()

# %%
# Multiple plots on one axis
from scipy.stats import norm
from random import uniform

fig, ax = plt.subplots()
x = np.linspace(-4, 4, 150)
for i in range(3):
    m, s = uniform(-1, 1), uniform(1, 2)
    y = norm.pdf(x, loc=m, scale=s)
    current_label = f'$\mu = {m:.2}$'
    ax.plot(x, y, linewidth=2, alpha=0.6, label=current_label)
ax.legend()
plt.show()

# %%
# Multiple subplots
num_rows, num_cols = 3, 2
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 12))
for i in range(num_rows):
    for j in range(num_cols):
        m, s = uniform(-1, 1), uniform(1, 2)
        x = norm.rvs(loc=m, scale=s, size=100)
        axes[i, j].hist(x, alpha=0.6, bins=20)
        t = f'$\mu = {m:.2}, \quad \sigma = {s:.2}$'
        axes[i, j].set(title=t, xticks=[-4, 0, 4], yticks=[])
plt.show()

# %%
# 3D plots
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm


def f(x, y):
    return np.cos(x**2 + y**2) / (1 + x**2 + y**2)

xgrid = np.linspace(-3, 3, 50)
ygrid = xgrid
x, y = np.meshgrid(xgrid, ygrid)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x,
                y,
                f(x, y),
                rstride=2, cstride=2,
                cmap=cm.jet,
                alpha=0.7,
                linewidth=0.25)
ax.set_zlim(-0.5, 1.0)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/mpl_toolkits/mplot3d/proj3d.py:135: RuntimeWarning: invalid value encountered in true_divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w

# %%
# Scatter plot with legend
import matplotlib.pyplot as plt
from numpy.random import rand


fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = rand(2, n)
    scale = 200.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.show()

# %% [markdown]
# ScyPy is open-software for mathematics, engineering and science.
# <p>
#     The scypi statistics subpackage (scipy.stats) supplies some estimation procedures, statistical tests and many random variable objects.

# %%
np.random.beta(5, 5, size=3)
# Out:
# array([0.53199861, 0.50114753, 0.50327825])

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
# %matplotlib inline

q = beta(5, 5)      # Beta(a, b), with a = b = 5
obs = q.rvs(2000)   # 2000 observations
grid = np.linspace(0.01, 0.99, 100)

fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(obs, bins=40, normed=True)
ax.plot(grid, q.pdf(grid), 'k-', linewidth=2)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
q.cdf(0.4)      # Cumulative distribution function
q.pdf(0.4)      # Density function
q.ppf(0.8)      # Quantile (inverse cdf) function
q.mean()

# %%
# implement simple linear regression
from scipy.stats import linregress

x = np.random.randn(200)
y = 2 * x + 0.1 * np.random.randn(200)
gradient, intercept, r_value, p_value, std_err = linregress(x, y)
gradient, intercept
# Out:
# (2.005823589945743, 0.005896149484193647)

# %% [markdown]
# References: <p>
#     http://www.numpy.org/
#     <br>
# https://quantecon.org
#     <br>
# https://matplotlib.org/gallery.html
#     <br>
# http://scipy-lectures.org/intro/matplotlib/matplotlib.html
#     <br>
#     https://www.scipy.org/
